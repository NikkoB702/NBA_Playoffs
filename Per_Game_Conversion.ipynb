# %%
import pandas as pd

# %%
csv_file_path = 'C:/Users/Home/NBA_Playoffs/Data/per_game_stats.csv'
df = pd.read_csv(csv_file_path)
df.head()
# Out:
#     Rk                    Team   G     MP    FG   FGA    FG%    3P   3PA  \
# 0  1.0       Sacramento Kings*  82  241.8  43.6  88.2  0.494  13.8  37.3
# 1  2.0  Golden State Warriors*  82  241.8  43.1  90.2  0.479  16.6  43.2
# 2  3.0          Atlanta Hawks*  82  242.1  44.6  92.4  0.483  10.8  30.5
# 3  4.0         Boston Celtics*  82  243.7  42.2  88.8  0.475  16.0  42.6
# 4  5.0  Oklahoma City Thunder*  82  242.1  43.1  92.6  0.465  12.1  34.1
#
#      3P%  ...    FT%   ORB   DRB   TRB   AST  STL  BLK   TOV    PF    PTS
# 0  0.369  ...  0.790   9.5  32.9  42.5  27.3  7.0  3.4  13.5  19.7  120.7
# 1  0.385  ...  0.794  10.5  34.1  44.6  29.8  7.2  3.9  16.3  21.4  118.9
# 2  0.352  ...  0.818  11.2  33.2  44.4  25.0  7.1  4.9  12.9  18.8  118.4
# 3  0.377  ...  0.812   9.7  35.6  45.3  26.7  6.4  5.2  13.4  18.8  117.9
# 4  0.356  ...  0.809  11.4  32.3  43.6  24.4  8.2  4.2  13.0  21.0  117.5
#
# [5 rows x 25 columns]

# %%
# Show column names and data types
print(df.dtypes)
# Out:
# Rk      float64
# Team     object
# G         int64
# MP      float64
# FG      float64
# FGA     float64
# FG%     float64
# 3P      float64
# 3PA     float64
# 3P%     float64
# 2P      float64
# 2PA     float64
# 2P%     float64
# FT      float64
# FTA     float64
# FT%     float64
# ORB     float64
# DRB     float64
# TRB     float64
# AST     float64
# STL     float64
# BLK     float64
# TOV     float64
# PF      float64
# PTS     float64
# dtype: object

# %%
# Show basic statistics for each column
print(df.describe())
# Out:
#               Rk     G          MP         FG        FGA        FG%  \
# count  30.000000  31.0   31.000000  31.000000  31.000000  31.000000
# mean   15.500000  82.0  241.787097  41.977419  88.316129   0.475452
# std     8.803408   0.0    0.761902   1.268519   2.530230   0.011958
# min     1.000000  82.0  240.600000  39.200000  83.800000   0.454000
# 25%     8.250000  82.0  241.200000  41.200000  86.350000   0.468000
# 50%    15.500000  82.0  241.800000  42.000000  88.300000   0.475000
# 75%    22.750000  82.0  242.100000  42.900000  90.150000   0.484000
# max    30.000000  82.0  243.700000  44.600000  92.600000   0.504000
#
#               3P        3PA        3P%         2P  ...        FT%        ORB  \
# count  31.000000  31.000000  31.000000  31.000000  ...  31.000000  31.000000
# mean   12.338710  34.209677   0.360161  29.645161  ...   0.782000  10.425806
# std     1.609281   3.630643   0.015520   2.008289  ...   0.026001   1.373795
# min    10.400000  28.900000   0.327000  24.800000  ...   0.733000   7.600000
# 25%    11.050000  31.800000   0.351000  28.300000  ...   0.758000   9.600000
# 50%    12.100000  33.300000   0.361000  29.800000  ...   0.784000  10.200000
# 75%    12.850000  35.500000   0.370000  31.050000  ...   0.795000  11.300000
# max    16.600000  43.200000   0.387000  33.900000  ...   0.835000  13.400000
#
#              DRB        TRB        AST        STL        BLK        TOV  \
# count  31.000000  31.000000  31.000000  31.000000  31.000000  31.000000
# mean   33.006452  43.425806  25.319355   7.287097   4.658065  14.093548
# std     1.557976   2.175924   1.740387   0.726976   0.721930   1.061425
# min    30.300000  38.800000  22.400000   6.100000   3.000000  11.700000
# 25%    32.050000  42.150000  24.050000   6.900000   4.150000  13.450000
# 50%    32.900000  43.400000  25.300000   7.100000   4.700000  14.100000
# 75%    33.950000  44.550000  26.100000   7.700000   5.200000  14.750000
# max    37.500000  48.600000  29.800000   9.400000   6.200000  16.300000
#
#               PF         PTS
# count  31.000000   31.000000
# mean   19.980645  114.687097
# std     1.075614    2.731513
# min    17.900000  109.500000
# 25%    18.950000  113.050000
# 50%    20.000000  114.400000
# 75%    20.600000  116.900000
# max    22.100000  120.700000
#
# [8 rows x 24 columns]

# %%
# Calculate the average points per game
average_points = df['PTS'].mean()
print(f"Average Points per Game: {average_points:.2f}")
# Out:
# Average Points per Game: 114.69

# %%
import matplotlib.pyplot as plt

# %%
# Example: Bar plot of points scored by each team
plt.figure(figsize=(12, 6))
plt.bar(df['Team'], df['PTS'])
plt.xticks(rotation=90)
plt.xlabel('Team')
plt.ylabel('Points')
plt.title('Points Scored by Each Team')
plt.show()

# %%
# List of playoff teams (replace with the actual team names)
playoff_teams = ["Brooklyn Nets", "Philadelphia 76ers", "Boston Celtics", "New York Knicks", "Cleveland Cavaliers", "Golden State Warriors", "Sacramento Kings", "Milwaukee Bucks", "Denver Nuggets", "Memphis Grizzlies", "Los Angeles Clippers", "Phoenix Suns", "Los Angeles Lakers", "Atlanta Hawks", "TBD", "TBD"]

# Filter the DataFrame to include only playoff teams
playoff_teams_df = df[df['Team'].isin(playoff_teams)]

# Display the filtered DataFrame
print(playoff_teams_df)

# Save the filtered DataFrame to a new CSV file
csv_file_path_playoffs = "playoff_teams.csv"
playoff_teams_df.to_csv(csv_file_path_playoffs, index=False)
